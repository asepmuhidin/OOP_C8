# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/OOP_C8/blob/main/ErrorHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BankAccount:
  def __init__(self,norek="Khabib",saldo=0):
    self.norek=norek
    self.saldo=saldo

  def transfer(self,target_account,amount):
    if amount > self.saldo:
      raise ValueError("Saldo tidak mencukupi..")

    self.saldo -=amount
    target_account.saldo +=amount

# %%
bca1=BankAccount()
print(f"No rekening anda :{bca1.norek}")
print(f"Saldo anda :{bca1.saldo}")
# Out:
# No rekening anda :Khabib
# Saldo anda :0

# %%
bca2=BankAccount("Agus",3000000)
print(f"No rekening anda :{bca2.norek}")
print(f"Saldo anda :{bca2.saldo:,}")
# Out:
# No rekening anda :Agus
# Saldo anda :3,000,000

# %%
amount_tf=10000
try:
  bca1.transfer(bca2,amount_tf)
except ValueError as e:
  print(e)

print(f"Transfer sejumlah Rp.{amount_tf} dari rekening {bca1.norek} ke {bca2.norek}")
print(f"Saldo anda :{bca1.saldo:,}")
print(f"Saldo anda :{bca2.saldo:,}")
# Out:
# Saldo tidak mencukupi..
# Transfer sejumlah Rp.10000 dari rekening Khabib ke Agus
# Saldo anda :0

# %%
amount_tf=10000
try:
  bca2.transfer(bca1,amount_tf)
except ValueError as e:
  print(e)

print(f"Transfer sejumlah Rp.{amount_tf:,} dari rekening {bca2.norek} ke {bca1.norek}")
print(f"Saldo {bca2.norek} :{bca2.saldo:,}")
print(f"Saldo {bca1.norek} :{bca1.saldo:,}")
# Out:
# Transfer sejumlah Rp.10,000 dari rekening Agus ke Khabib
# Saldo Agus :2,980,000
# Saldo Khabib :20,000

# %%
print(f"Saldo anda :{bca1.saldo:,}")
# Out:
# Saldo anda :20,000
